# %%
import pandas as pd

salaires = pd.read_csv("data/salaires_EQTP.csv")
creations = pd.read_csv("data/Variable_Y.csv")

population = pd.read_csv("/Users/tristan/info/ENSAE/2A/python_DS_2A/data/population_regions_1975_2025.csv")
# colonnes : region, annee, population
