# %%
import pandas as pd

salaires = pd.read_csv("data/salaires_EQTP.csv")
creations = pd.read_csv("data/Variable_Y.csv")

population = pd.read_csv("population.csv")
# colonnes : region, annee, population

df = (
    salaires
    .merge(creations, on=["region", "annee"], how="inner")
    .merge(population, on=["region", "annee"], how="inner")
)
